# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('base ball.csv')
df=pd.DataFrame(df)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# From above we learn that data set do not contains any string values we have integers and ERA column contains float values.

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# We have data set of dimension 30 Rows and 17 Columns

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# We could see the maximum and minimum values present in data set, also the mean, median values present in data set

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Here using above command we could see no missing values present in dataset.
#
# Runs (R), At Bats(AB), Hits(H), Doubles(2B), Triples(3B), Homeruns(HR), Walks(BB),Strikeouts(SO), Stolen Bases(SB), Runs Allowed(RA), Earned Runs(ER), Earned Run Average (ERA), Shutouts(SHO), Saves(SV), and Errors(E).

# %%
df.plot(kind='box',subplots=True, layout=(3,6))
# Out:
# W         AxesSubplot(0.125,0.657941;0.110714x0.222059)
# R      AxesSubplot(0.257857,0.657941;0.110714x0.222059)
# AB     AxesSubplot(0.390714,0.657941;0.110714x0.222059)
# H      AxesSubplot(0.523571,0.657941;0.110714x0.222059)
# 2B     AxesSubplot(0.656429,0.657941;0.110714x0.222059)
# 3B     AxesSubplot(0.789286,0.657941;0.110714x0.222059)
# HR        AxesSubplot(0.125,0.391471;0.110714x0.222059)
# BB     AxesSubplot(0.257857,0.391471;0.110714x0.222059)
# SO     AxesSubplot(0.390714,0.391471;0.110714x0.222059)
# SB     AxesSubplot(0.523571,0.391471;0.110714x0.222059)
# RA     AxesSubplot(0.656429,0.391471;0.110714x0.222059)
# ER     AxesSubplot(0.789286,0.391471;0.110714x0.222059)
# ERA          AxesSubplot(0.125,0.125;0.110714x0.222059)
# CG        AxesSubplot(0.257857,0.125;0.110714x0.222059)
# SHO       AxesSubplot(0.390714,0.125;0.110714x0.222059)
# SV        AxesSubplot(0.523571,0.125;0.110714x0.222059)
# E         AxesSubplot(0.656429,0.125;0.110714x0.222059)
# ...

# %% [markdown]
# We could see the outliers in E column.

# %%
sns.boxplot('R',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R'>

# %%
sns.boxplot('ERA',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ERA'>

# %%
sns.boxplot('SHO',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SHO'>

# %%
sns.boxplot('SV',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SV'>

# %%
sns.boxplot('E',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='E'>

# %% [markdown]
# Upon detail analysis we found that there are lagre number of outliers in E column while SV SHO ERA and R column have very few outliers.
#
# Hence we will remove these outliers in further.

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We could see the negative skewness  in 2B  and SO columns.

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='R',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='R'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(y = 'AB',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='AB'>

# %% [markdown]
# In AB column we have 5485 as highest count of 2.

# %%
plt.figure(figsize=(10,6))
sns.countplot(y = 'H',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='H'>

# %% [markdown]
# In H column highest value 2 is for 1363.

# %%
plt.figure(figsize=(10,6))
sns.countplot(y = '2B',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='2B'>

# %% [markdown]
# Here we could see multiple values with count 3 and one value with count 3.

# %%
corr_mat=df.corr()
plt.figure(figsize=[14,12])
sns.heatmap(corr_mat,annot=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# E, ERA, ER, RA, SB 3B AND AB   are having negative relationship with Win W.

# %%
def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(df[variable])
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist ".format(variable))
    plt.show()

# %%
numericVar = ["E","W"]
for n in numericVar:
    plot_hist(n)

# %% [markdown]
# We can see the relationship or E column and W column, here we conclude that less the frequency of error more are the chances to win.

# %%
g = sns.factorplot(x = "W", y = "E", data = df, kind = "bar", size = 6)
g.set_ylabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["3B","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "3B", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["HR","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "HR", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["BB","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "BB", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["SO","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "SO", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["SB","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "SB", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["RA","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "RA", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["ER","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "ER", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["ERA","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "ERA", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["CG","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "CG", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["SHO","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "SHO", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
numericVar = ["SV","W"]
for n in numericVar:
    plot_hist(n)

# %%
g = sns.factorplot(x = "W", y = "SV", data = df, kind = "bar", size = 6)
g.set_xlabels("Win Probability")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3710: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# From above we understand that the all the columns have certain relation ship with W hence we cannot modify or remove any data.
#
# W is an target variable.

# %%
sns.pairplot(df)

# %% [markdown]
# The pair plot shows us the relationship between the columns, and we understand that AB, H, 3B, RA, ER, ERA and E have negative or inverse relationship with Win(w).

# %% [markdown]
# We will now treate the outliers present in E and other columns of data set

# %%
plt.scatter(df['AB'],df['W'])

# %%
plt.scatter(df['H'],df['W'])

# %%
plt.scatter(df['3B'],df['W'])

# %%
plt.scatter(df['RA'],df['W'])

# %%
plt.scatter(df['ER'],df['W'])

# %%
plt.scatter(df['ERA'],df['W'])

# %%
plt.scatter(df['E'],df['W'])

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %% [markdown]
# We performed the Z score method to treat the outliers present in Data set

# %%
threshold=2
print(np.where(z>2))
# Out:
# (array([ 0,  2,  5,  5,  8, 11, 14, 15, 15, 15, 15, 16, 17, 17, 19, 22, 23,
#        25, 27, 29, 29, 29], dtype=int64), array([ 8, 13,  1,  6, 15,  6, 16, 10, 11, 12, 15, 16,  8, 14,  9,  4,  6,
#        14,  9, 10, 11, 12], dtype=int64))

# %%
from scipy.stats import skew
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Skewness +/-0.65 is acceptable Here we could see the skewness in Newspaper column. But Column R CG and E are having more than 0.7 hence we will have to treate the skewness.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
for col in df:
    print (col)
    print(skew (df[col]))
    
    plt.figure()
    sns.displot(df[col])
    plt.show()
# Out:
# W
# 0.04470076997798572
# R
# 1.1398931660307043
# AB
# 0.17413429032352498
# H
# 0.6362644174348592
# 2B
# -0.2189534077067715
# 3B
# 0.12293523975827839
# HR
# 0.49025146140832154
# BB
# 0.15046085271433388
# SO
# -0.14815122992357777
# SB
# 0.4555569751737513
# RA
# 0.04341475534967941
# ER
# 0.055732557686200515
# ERA
# 0.0506268488741678
# CG
# 0.6994790420153237
# SHO
# 0.5370985776239573
# SV
# 0.6241798071870271
# E
# 0.8449922672006391

# %%
df["H"] = np.sqrt(df["H"])
skew(df['H'])
# Out:
# 0.6166263385531084

# %%
df["E"] = np.sqrt(df["E"])
skew(df['E'])
# Out:
# 0.7247701257697083

# %%
df["R"] = np.sqrt(df["R"])
skew(df['R'])
# Out:
# 0.9195532515863517

# %%
df["CG"] = np.sqrt(df["CG"])
skew(df['CG'])
# Out:
# -0.2956808707860975

# %%
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.649567
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.311476
# SHO    0.565790
# SV     0.657524
# E      0.763487
# dtype: float64

# %% [markdown]
# We have used the log tranfromation to remove the skewness from the data set

# %%
df
# Out:
#       W          R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER  \
# 0    95  26.907248  5575  38.691084  300  42  139  383   973  104  641  601
# 1    83  26.381812  5467  36.728735  277  44  156  439  1264   70  700  653
# 2    81  25.865034  5439  37.349699  303  29  141  533  1157   86  640  584
# 3    76  24.939928  5533  37.161808  260  27  136  404  1231   68  701  643
# 4    74  26.248809  5605  38.923001  289  49  151  455  1259   83  803  746
# 5    93  29.849623  5509  38.470768  308  17  232  570  1151   88  670  609
# 6    87  27.640550  5567  37.376463  272  19  212  554  1227   63  698  652
# 7    81  26.702060  5485  37.013511  246  20  217  418  1331   44  693  646
# 8    80  25.377155  5485  37.188708  278  32  167  436  1310   87  642  604
# 9    78  27.349589  5640  38.665230  294  33  161  478  1148   71  753  694
# 10   88  27.404379  5511  37.669616  279  32  172  503  1233  101  733  680
# ...

# %% [markdown]
# Model

# %% [markdown]
# Data set is an example of supervised regression hence we will perform regression modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import  train_test_split, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
x=df.iloc[:,1:17]

# %%
x
# Out:
#             R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   26.907248  5575  38.691084  300  42  139  383   973  104  641  601  3.73
# 1   26.381812  5467  36.728735  277  44  156  439  1264   70  700  653  4.07
# 2   25.865034  5439  37.349699  303  29  141  533  1157   86  640  584  3.67
# 3   24.939928  5533  37.161808  260  27  136  404  1231   68  701  643  3.98
# 4   26.248809  5605  38.923001  289  49  151  455  1259   83  803  746  4.64
# 5   29.849623  5509  38.470768  308  17  232  570  1151   88  670  609  3.80
# 6   27.640550  5567  37.376463  272  19  212  554  1227   63  698  652  4.03
# 7   26.702060  5485  37.013511  246  20  217  418  1331   44  693  646  4.05
# 8   25.377155  5485  37.188708  278  32  167  436  1310   87  642  604  3.74
# 9   27.349589  5640  38.665230  294  33  161  478  1148   71  753  694  4.31
# 10  27.404379  5511  37.669616  279  32  172  503  1233  101  733  680  4.24
# ...

# %%
y=df.iloc[:,0]

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print (x_train.shape, x_test.shape)
print (y_train.shape, y_test.shape)
# Out:
# (24, 16) (6, 16)
# (24,) (6,)

# %% [markdown]
# We will fit the data using the standared Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred=lm.predict(x_test)

print('Prediction',pred)
print('Actual value', y_test)
# Out:
# Prediction [86.56517089 86.10322003 75.08080169 80.1802905  75.20761416 75.61290272]
# Actual value 15    100
# 21     83
# 5      93
# 2      81
# 28     74
# 1      83
# Name: W, dtype: int64

# %% [markdown]
# Evaluation Matrix

# %%
print('RF Mean absolute error:',mean_absolute_error(y_test,predrf))
print("r2 score is ", r2_score(y_test,pred))
print('Root mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
print('Mean squared error is ',mean_squared_error(y_test,pred))
# Out:
# RF Mean absolute error: 7.173888888888854
# r2 score is  -0.3166655433588843
# Root mean Squared Error: 9.72900935092342
# Mean squared error is  94.65362295035534

# %% [markdown]
# r2 score -> coeffiecient of determination is the proportion of the variance in the dependent variable that is predicatable from the independent variable (s) i.e change coming in y whenever x is being changed.

# %%
print("lm_coefficeient is", lm.coef_)
print("lm_intercept is ", lm.intercept_)
print('Lm score is ',lm.score(x_train,y_train))
# Out:
# lm_coefficeient is [ 10.79293361  -5.92576312   0.42462685  -1.80883219  -1.0809159
#   -5.02061235  -2.95737775   0.86562986  -0.20921459  15.24470141
#   34.32418768 -54.97553526   2.07068742   0.98324889   3.092564
#   -1.83351042]
# lm_intercept is  79.79166666666671
# Lm score is  0.9704649635990992

# %%
from sklearn.model_selection  import cross_val_score as cvs
def cross_val(model_name,model,x,y,cv):
    
    scores = cvs(model, x, y, cv=cv)
    print(f'{model_name} Scores:')
    for i in scores:
        print(round(i,2))
    print(f'Average {model_name} score: {round(scores.mean(),4)}')

# %%
cross_val(lm,LinearRegression(),x,y,5)
# Out:
# LinearRegression() Scores:
# 0.68
# -2.93
# 0.46
# 0.71
# 0.45
# Average LinearRegression() score: -0.1266

# %% [markdown]
# Random forest regressor

# %%
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
RF= RandomForestRegressor(n_estimators=200,max_depth=5, min_samples_leaf=100,n_jobs=4,random_state=22)
RF.fit(x_train,y_train)
y_pred = RF.predict(x_test)

# %%
predrf=RF.predict(x_test)
print('RF Prediction :',predrf)
print('Actual value ', y_test)
# Out:
# RF Prediction : [79.88791667 79.88791667 79.88791667 79.88791667 79.88791667 79.88791667]
# Actual value  15    100
# 21     83
# 5      93
# 2      81
# 28     74
# 1      83
# Name: W, dtype: int64

# %%
print('RF Mean absolute error:',mean_absolute_error(y_test,predrf))
print("RF r2 score is ", r2_score(y_test,predrf))
print('RF Root mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
print('RF Mean squared error is ',mean_squared_error(y_test,predrf))
# Out:
# RF Mean absolute error: 7.741388888888878
# RF r2 score is  -0.464521737345438
# RF Root mean Squared Error: 10.260742685175801
# RF Mean squared error is  105.28284045138871

# %%
cross_val(RF,RandomForestRegressor(),x,y,5)
# Out:
# RandomForestRegressor(max_depth=5, min_samples_leaf=100, n_estimators=200,
#                       n_jobs=4, random_state=22) Scores:
# 0.21
# -4.85
# 0.19
# 0.4
# 0.66
# Average RandomForestRegressor(max_depth=5, min_samples_leaf=100, n_estimators=200,
#                       n_jobs=4, random_state=22) score: -0.6794

# %% [markdown]
# Lasso Ridge

# %%
from sklearn.linear_model import Lasso,Ridge
ls=Lasso(alpha=0.01)
ls.fit(x_train,y_train)
print('Lasso Score is ',ls.score(x_train,y_train) )
# Out:
# Lasso Score is  0.964325254803718
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5483872721331409, tolerance: 0.2571958333333333
#   model = cd_fast.enet_coordinate_descent(

# %%
print('ls Mean absolute error:',mean_absolute_error(y_test,predrf))
print("ls r2 score is ", r2_score(y_test,predrf))
print('ls Root mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrf)))
print('ls Mean squared error is ',mean_squared_error(y_test,predrf))
# Out:
# ls Mean absolute error: 7.741388888888878
# ls r2 score is  -0.464521737345438
# ls Root mean Squared Error: 10.260742685175801
# ls Mean squared error is  105.28284045138871

# %%
cross_val(ls,Lasso(),x,y,5)
# Out:
# Lasso(alpha=0.01) Scores:
# 0.63
# -3.34
# 0.31
# 0.68
# 0.93
# Average Lasso(alpha=0.01) score: -0.1585
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18.593407725608245, tolerance: 0.24669583333333336
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Random Forest Regression is the best model that we can use to predict Win (W) with 75% accuracy.

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'bootstrap': [True],
    'max_depth': [5,10],
    'min_samples_leaf': [3],
    'min_samples_split': [8],
    'n_estimators': [100]}

RF = RandomForestRegressor()
                     
                     
grid_search = GridSearchCV(estimator = RF, param_grid = param_grid, cv = 4, n_jobs = -1, verbose = 3)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 4 folds for each of 2 candidates, totalling 8 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   8 | elapsed:    5.5s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.9s finished
# GridSearchCV(cv=4, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [5, 10],
#                          'min_samples_leaf': [3], 'min_samples_split': [8],
#                          'n_estimators': [100]},
#              verbose=3)

# %%
RF_Root_mean_Squared_Error_GSV = np.sqrt(mean_squared_error(y_train, grid_search.predict(x_train)))
print('RF Root mean Squared Error GSV:',RF_Root_mean_Squared_Error_GSV )
# Out:
# RF Root mean Squared Error GSV: 4.137909733608629

# %% [markdown]
# Saving the model.

# %%
import joblib
joblib.dump(RF,"Baseball.pkl")
# Out:
# ['Baseball.pkl']
